# %%
import pandas as pd

# %%
arrests = pd.read_csv("arrests.csv")
arrests
arrest_count = arrests.groupby("INCIDENTNEIGHBORHOOD").count()["PK"]
arrest_count = arrest_count.sort_values(ascending = True)
arrest_count_df = arrest_count.to_frame()
arrest_count_df = arrest_count_df.reset_index(level = 'INCIDENTNEIGHBORHOOD')
arrest_count_df.columns=["Neighborhood", "arrests"]

arrest_count_df
# Out:
#                    Neighborhood  arrests
# 0       Mt. Oliver Neighborhood        2
# 1        Troy Hill-Herrs Island        6
# 2               Mt. Oliver Boro       12
# 3                     Ridgemont       13
# 4                 Regent Square       19
# 5                Swisshelm Park       20
# 6                 New Homestead       22
# 7                Chartiers City       23
# 8             Central Northside       23
# 9                 East Carnegie       27
# 10                    St. Clair       30
# 11               Outside County       36
# 12                Outside State       39
# 13                      Oakwood       44
# 14                  Summer Hill       45
# 15                      Windgap       60
# 16                         Hays       62
# 17                    Fairywood       62
# 18                   Glen Hazel       69
# 19               Allegheny West       75
# 20  Golden Triangle/Civic Arena       83
# 21                 Mount Oliver       89
# 22                  Polish Hill       98
# 23            Arlington Heights      100
# 24                Lincoln Place      101
# 25             Duquesne Heights      103
# 26                       Esplen      105
# 27                   Friendship      107
# 28                  Morningside      111
# 29          Upper Lawrenceville      113
# ..                          ...      ...
# 68                      Larimer      452
# 69            South Side Slopes      458
# 70                  North Shore      470
# 71             Crawford-Roberts      470
# 72           Central North Side      487
# 73                     Fineview      496
# 74                    Allentown      539
# 75                    Shadyside      540
# 76                   Bloomfield      551
# 77                  Middle Hill      569
# 78                   East Hills      580
# 79             Brighton Heights      612
# 80                  Perry South      637
# 81             Allegheny Center      651
# 82                     Sheraden      660
# 83                    Beechview      686
# 84                    Brookline      693
# 85     Lincoln-Lemington-Belmar      697
# 86                    Hazelwood      706
# 87                    Knoxville      752
# 88                        Bluff      783
# 89             Mount Washington      838
# 90           Marshall-Shadeland      853
# 91                 East Liberty      995
# 92               Homewood North     1036
# 93               Homewood South     1138
# 94               East Allegheny     1235
# 95                      Carrick     1313
# 96             South Side Flats     1953
# 97    Central Business District     2131
#
# [98 rows x 2 columns]

# %%
fire = pd.read_csv("fire.csv")
fire_count = fire.groupby("neighborhood").count()["call_no"]
fire_count = fire_count.sort_values(ascending = True)
fire_count_df = fire_count.to_frame()
fire_count_df = fire_count_df.reset_index(level = 'neighborhood')
fire_count_df.columns=["Neighborhood", "fires"]
fire_count_df
# Out:
#                  Neighborhood  fires
# 0        Mount Oliver Borough      4
# 1               Regent Square      6
# 2               East Carnegie      6
# 3                  Mt. Oliver      7
# 4           Arlington Heights      9
# 5                     Oakwood     10
# 6                        Hays     11
# 7              Chartiers City     11
# 8              Swisshelm Park     11
# 9                   St. Clair     11
# 10                  Ridgemont     12
# 11                     Esplen     15
# 12                    Windgap     16
# 13                    Bon Air     16
# 14                Summer Hill     16
# 15                   West End     16
# 16                 Glen Hazel     17
# 17                South Shore     18
# 18                  Fairywood     18
# 19              Spring Garden     19
# 20              New Homestead     20
# 21                   Westwood     21
# 22           Duquesne Heights     23
# 23                Polish Hill     24
# 24                 Friendship     25
# 25                Morningside     26
# 26       California-Kirkbride     31
# 27          Bedford Dwellings     31
# 28             Allegheny West     32
# 29                    Chateau     34
# ..                        ...    ...
# 61      Spring Hill-City View     80
# 62                 Greenfield     82
# 63                Perry North     83
# 64                      Bluff     87
# 65                  Allentown     89
# 66              North Oakland     92
# 67          Central Northside     94
# 68        Squirrel Hill North     96
# 69         Marshall-Shadeland     97
# 70                Beltzhoover     97
# 71                  Beechview    101
# 72                    Larimer    102
# 73           Brighton Heights    105
# 74                  Knoxville    116
# 75                 Bloomfield    120
# 76                 East Hills    121
# 77                  Shadyside    125
# 78                  Brookline    127
# 79             Homewood South    128
# 80                Perry South    128
# 81                   Sheraden    134
# 82             Homewood North    145
# 83           Mount Washington    145
# 84   Lincoln-Lemington-Belmar    146
# 85               East Liberty    148
# 86        Squirrel Hill South    178
# 87                  Hazelwood    183
# 88           South Side Flats    184
# 89  Central Business District    186
# 90                    Carrick    220
#
# [91 rows x 2 columns]

# %%
population = pd.read_csv("population.csv")
population_sorted = population.sort_values("Neighborhood")
population_sorted.columns=["Neighborhood", "id", "population", "Margin of error"]
population_sorted
# Out:
#                  Neighborhood  id  population  Margin of error
# 0            Allegheny Center   1        1411       196.000000
# 1              Allegheny West   2         343        96.000000
# 2                   Allentown   3        2558       449.773276
# 3                   Arlington   4        1852       348.188168
# 4           Arlington Heights   5         272       126.000000
# 5                  Banksville   6        3858       581.107563
# 6           Bedford Dwellings   7        1349       180.000000
# 7                   Beechview   8        8078       719.658252
# 8                 Beltzhoover   9        1702       343.072879
# 9                  Bloomfield  10        8669       491.348145
# 10                      Bluff  11        6294       395.761292
# 11                    Bon Air  12         920       171.000000
# 12           Brighton Heights  13        7421       560.572921
# 13                  Brookline  14       13160       943.065215
# 14       California-Kirkbride  15         803       136.000000
# 15                    Carrick  16       10122       826.666196
# 16  Central Business District  17        4060       458.026200
# 17      Central Lawrenceville  18        4775       383.429263
# 18          Central Northside  19        2892       345.741233
# 19            Central Oakland  20        5822       659.416409
# 20             Chartiers City  21         560       172.000000
# 21                    Chateau  22           3         3.000000
# 22            Crafton Heights  23        3964       384.981818
# 23           Crawford-Roberts  24        2225       329.528451
# 24           Duquesne Heights  25        2522       350.750624
# 25             East Allegheny  26        2095       284.401125
# 26              East Carnegie  27         610       120.000000
# 27                 East Hills  28        2859       435.754518
# 28               East Liberty  29        5537       612.871112
# 29                    Elliott  30        2491       405.687072
# ..                        ...  ..         ...              ...
# 61                Perry North  62        3771       398.571198
# 62                Perry South  63        3398       479.242110
# 63               Point Breeze  64        5414       333.955087
# 64         Point Breeze North  65        1732       261.024903
# 65                Polish Hill  66        1331       174.315805
# 66              Regent Square  67        1033       101.000000
# 67                  Ridgemont  68         314       109.000000
# 68                  Shadyside  69       13562       861.984919
# 69                   Sheraden  70        5684       740.850862
# 70              South Oakland  71        2921       513.468597
# 71                South Shore  72          12        14.000000
# 72           South Side Flats  73        6292       747.592135
# 73          South Side Slopes  74        4583       516.263499
# 74              Spring Garden  75         840       151.558570
# 75      Spring Hill-City View  76        2456       423.935137
# 76        Squirrel Hill North  77       11336       767.783173
# 77        Squirrel Hill South  78       16042       889.712313
# 78                  St. Clair  79         270        96.000000
# 79            Stanton Heights  80        4761       418.092095
# 80             Strip District  81         747        94.000000
# 81                Summer Hill  82        1191        92.000000
# 82             Swisshelm Park  83        1345       106.000000
# 83            Terrace Village  84        2292       264.463608
# 84                  Troy Hill  85        2283       323.167139
# 85                 Upper Hill  86        1884       408.074748
# 86        Upper Lawrenceville  87        2754       435.708618
# 87                   West End  88         235       138.000000
# 88               West Oakland  89        1717       285.001754
# 89                   Westwood  90        3537       407.982843
# 90                    Windgap  91        1534       367.828765
#
# [91 rows x 4 columns]

# %%
neighborhood_series = pd.Series(population_sorted["Neighborhood"])
neighborhood_series
neighborhood_series_df = neighborhood_series.to_frame()
neighborhood_series_df
# Out:
#                  Neighborhood
# 0            Allegheny Center
# 1              Allegheny West
# 2                   Allentown
# 3                   Arlington
# 4           Arlington Heights
# 5                  Banksville
# 6           Bedford Dwellings
# 7                   Beechview
# 8                 Beltzhoover
# 9                  Bloomfield
# 10                      Bluff
# 11                    Bon Air
# 12           Brighton Heights
# 13                  Brookline
# 14       California-Kirkbride
# 15                    Carrick
# 16  Central Business District
# 17      Central Lawrenceville
# 18          Central Northside
# 19            Central Oakland
# 20             Chartiers City
# 21                    Chateau
# 22            Crafton Heights
# 23           Crawford-Roberts
# 24           Duquesne Heights
# 25             East Allegheny
# 26              East Carnegie
# 27                 East Hills
# 28               East Liberty
# 29                    Elliott
# ..                        ...
# 61                Perry North
# 62                Perry South
# 63               Point Breeze
# 64         Point Breeze North
# 65                Polish Hill
# 66              Regent Square
# 67                  Ridgemont
# 68                  Shadyside
# 69                   Sheraden
# 70              South Oakland
# 71                South Shore
# 72           South Side Flats
# 73          South Side Slopes
# 74              Spring Garden
# 75      Spring Hill-City View
# 76        Squirrel Hill North
# 77        Squirrel Hill South
# 78                  St. Clair
# 79            Stanton Heights
# 80             Strip District
# 81                Summer Hill
# 82             Swisshelm Park
# 83            Terrace Village
# 84                  Troy Hill
# 85                 Upper Hill
# 86        Upper Lawrenceville
# 87                   West End
# 88               West Oakland
# 89                   Westwood
# 90                    Windgap
#
# [91 rows x 1 columns]

# %%
'''combined = pd.merge(fire_count_df,
                    neighborhood_series_df,
                    on = '',
                    how = 'outer')
combined'''
combined = pd.merge(population_sorted,
                   neighborhood_series_df,
                   on = 'Neighborhood'
                   )
combined1 = pd.merge(combined,
                     fire_count_df,
                     on = "Neighborhood"
                     )
combined2 = pd.merge(combined1,
                     arrest_count_df,
                     on = "Neighborhood"
                     )

# %%
average = []
thing = len(combined2)
for index, row in combined2.iterrows():
    average.append( (row["arrests"]+row["fires"])/row["population"] )
combined2["incident score"] = average

# %%
final = combined2.sort_values(ascending = True, by = "incident score")
final = final[['Neighborhood', 'population', 'fires', 'arrests', 'incident score']]
final = final.set_index(['Neighborhood'])
final
# Out:
#                            population  fires  arrests  incident score
# Neighborhood
# Squirrel Hill North             11336     96      151        0.021789
# Swisshelm Park                   1345     11       20        0.023048
# Regent Square                    1033      6       19        0.024201
# North Oakland                    9602     92      223        0.032806
# Stanton Heights                  4761     43      115        0.033186
# Squirrel Hill South             16042    178      439        0.038462
# Westwood                         3537     21      119        0.039582
# Central Northside                2892     94       23        0.040456
# Lincoln Place                    3499     44      101        0.041440
# Morningside                      3262     26      111        0.041999
# New Homestead                     973     20       22        0.043165
# Point Breeze                     5414     57      184        0.044514
# Greenfield                       7690     82      279        0.046944
# Shadyside                       13562    125      540        0.049034
# Banksville                       3858     49      141        0.049248
# Windgap                          1534     16       60        0.049544
# Highland Park                    6810     54      286        0.049927
# Duquesne Heights                 2522     23      103        0.049960
# Oakwood                          1058     10       44        0.051040
# Summer Hill                      1191     16       45        0.051217
# Upper Lawrenceville              2754     35      113        0.053740
# East Carnegie                     610      6       27        0.054098
# Overbrook                        3682     38      166        0.055405
# Chartiers City                    560     11       23        0.060714
# Brookline                       13160    127      693        0.062310
# Central Oakland                  5822     68      304        0.063896
# Fairywood                        1181     18       62        0.067739
# Central Lawrenceville            4775     58      272        0.069110
# Lower Lawrenceville              2572     40      143        0.071151
# Friendship                       1840     25      107        0.071739
# ...                               ...    ...      ...             ...
# Knoxville                        4255    116      752        0.203995
# East Liberty                     5537    148      995        0.206429
# Hazelwood                        4257    183      706        0.208833
# Spring Hill-City View            2456     80      434        0.209283
# Perry South                      3398    128      637        0.225132
# California-Kirkbride              803     31      152        0.227895
# Beltzhoover                      1702     97      313        0.240893
# East Hills                       2859    121      580        0.245191
# Allentown                        2558     89      539        0.245504
# Crawford-Roberts                 2225     77      470        0.245843
# Bedford Dwellings                1349     31      336        0.272053
# Northview Heights                1545     52      379        0.278964
# Allegheny West                    343     32       75        0.311953
# Larimer                          1641    102      452        0.337599
# South Side Flats                 6292    184     1953        0.339638
# Homewood North                   3371    145     1036        0.350341
# Middle Hill                      1760     79      569        0.368182
# Esplen                            309     15      105        0.388350
# Arlington Heights                 272      9      100        0.400735
# Strip District                    747     35      269        0.406961
# Fineview                         1270     38      496        0.420472
# Allegheny Center                 1411     46      651        0.493976
# Homewood West                     850     43      417        0.541176
# Homewood South                   2276    128     1138        0.556239
# Central Business District        4060    186     2131        0.570690
# East Allegheny                   2095     76     1235        0.625776
# West End                          235     16      153        0.719149
# North Shore                       205     48      470        2.526829
# South Shore                        12     18      158       14.666667
# Chateau                             3     34      262       98.666667
#
# [89 rows x 4 columns]

# %%
#regular bar graph
final['incident score'].plot(kind = 'bar', figsize = (35, 15), title = 'Incident Score by Neighborhood')

# %%
#horizontal bar graph
final['incident score'].plot(kind = 'barh', figsize = (35, 15), title = 'Incident Score by Neighborhood')

# %%
#in order to better read the data, dropped Chateau from the data, which had an incident score around 84 points higher than the second most
final_without_Chateau = final.drop('Chateau')
final_without_Chateau['incident score'].plot(kind = 'bar', figsize = (35, 15), title = 'Incident Score by Neighborhood')
